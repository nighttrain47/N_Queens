# %% [markdown]
# Bài toán 8 con hậu

# %%
import numpy as np

# Hàm kiểm tra xem đã tìm được một lời giải hợp lệ chưa
def is_valid_state(state, num_queens):
    # Một lời giải hợp lệ khi đã đặt đủ số quân hậu
    return len(state) == num_queens

# Hàm lấy các vị trí (cột) ứng viên cho hàng tiếp theo
def get_candidates(state, num_queens):
    # Nếu chưa có quân hậu nào, tất cả các cột đều là ứng viên
    if not state:
        return range(num_queens)

    # Vị trí (hàng) hiện tại đang cần đặt quân hậu
    position = len(state)
    # Bắt đầu với tất cả các cột có thể
    candidates = set(range(num_queens))

    # Lặp qua các quân hậu đã đặt để loại bỏ các vị trí bị tấn công
    for row, col in enumerate(state):
        # 1. Loại bỏ cột đã có quân hậu (tấn công theo chiều dọc)
        candidates.discard(col)
        
        # 2. Loại bỏ các vị trí bị tấn công theo đường chéo
        # Tính khoảng cách hàng giữa vị trí hiện tại và quân hậu đã đặt
        # === PHẦN SỬA 1 ===
        dist = position - row 
        
        # Loại bỏ vị trí trên đường chéo (xuống-phải)
        candidates.discard(col + dist)
        # Loại bỏ vị trí trên đường chéo (xuống-trái)
        candidates.discard(col - dist)

    return candidates

# Hàm tìm kiếm đệ quy (backtracking)
def search(state, solutions, num_queens):
    # Nếu đã tìm thấy một lời giải hoàn chỉnh, thêm vào danh sách và dừng nhánh này
    if is_valid_state(state, num_queens):
        solutions.append(state.copy())
        return
    
    # Lặp qua các ứng viên hợp lệ cho hàng hiện tại
    for candidate in get_candidates(state, num_queens):
        # Đặt thử quân hậu vào vị trí ứng viên
        state.append(candidate)
        # Tiếp tục tìm kiếm cho hàng tiếp theo
        search(state, solutions, num_queens)
        # Quay lui (backtrack): gỡ quân hậu vừa đặt ra để thử phương án khác
        # Dòng print này giúp theo dõi quá trình quay lui
        # print(f"Backtracking from state: {state}") 
        state.pop() # Sử dụng pop() hiệu quả hơn remove(candidate) khi phần tử cuối cùng luôn là phần tử cần xóa

# Hàm chính để giải bài toán
def solve(num_queens):
    solutions = []
    state = []
    search(state, solutions, num_queens)
    return solutions

# Hàm main chạy chương trình
if __name__ == "__main__":
    try:
        num_queens = int(input("Nhap so quan hau (ví dụ: 4 hoặc 8): "))
        if num_queens <= 0:
            print("Vui lòng nhập một số nguyên dương.")
        else:
            print(f"Bàn cờ trống {num_queens}x{num_queens}:")
            empty_board = np.full((num_queens, num_queens), "-")
            print(empty_board)
            
            solutions = solve(num_queens)
            
            print(f"\n=> Tong so loi giai tim duoc: {len(solutions)}")
            
            # In ra từng lời giải
            for index, solution in enumerate(solutions, start=1):
                board = np.full((num_queens, num_queens), "-")
                for row, col in enumerate(solution):
                    board[row][col] = 'Q'
                
                print(f"\n--- Loi giai {index}: {solution} ---")
                
                # In bàn cờ
                for row in board:
                    print(" ".join(row))
                
                # In theo tọa độ
                # === PHẦN SỬA 2 ===
                print("Toa do cac quan hau (hàng, cột):", end=" ")
                coordinates = []
                for row, col in enumerate(solution):
                    coordinates.append(f"({row}, {col})")
                print(", ".join(coordinates))

    except ValueError:
        print("Đầu vào không hợp lệ. Vui lòng nhập một số nguyên.")
# Out:
# Bàn cờ trống 8x8:
# [['-' '-' '-' '-' '-' '-' '-' '-']
#  ['-' '-' '-' '-' '-' '-' '-' '-']
#  ['-' '-' '-' '-' '-' '-' '-' '-']
#  ['-' '-' '-' '-' '-' '-' '-' '-']
#  ['-' '-' '-' '-' '-' '-' '-' '-']
#  ['-' '-' '-' '-' '-' '-' '-' '-']
#  ['-' '-' '-' '-' '-' '-' '-' '-']
#  ['-' '-' '-' '-' '-' '-' '-' '-']]
#
# => Tong so loi giai tim duoc: 92
#
# --- Loi giai 1: [0, 4, 7, 5, 2, 6, 1, 3] ---
# Q - - - - - - -
# - - - - Q - - -
# - - - - - - - Q
# - - - - - Q - -
# - - Q - - - - -
# - - - - - - Q -
# - Q - - - - - -
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 0), (1, 4), (2, 7), (3, 5), (4, 2), (5, 6), (6, 1), (7, 3)
#
# --- Loi giai 2: [0, 5, 7, 2, 6, 3, 1, 4] ---
# Q - - - - - - -
# - - - - - Q - -
# - - - - - - - Q
# - - Q - - - - -
# - - - - - - Q -
# - - - Q - - - -
# - Q - - - - - -
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 0), (1, 5), (2, 7), (3, 2), (4, 6), (5, 3), (6, 1), (7, 4)
#
# --- Loi giai 3: [0, 6, 3, 5, 7, 1, 4, 2] ---
# Q - - - - - - -
# - - - - - - Q -
# - - - Q - - - -
# - - - - - Q - -
# - - - - - - - Q
# - Q - - - - - -
# - - - - Q - - -
# - - Q - - - - -
# Toa do cac quan hau (hàng, cột): (0, 0), (1, 6), (2, 3), (3, 5), (4, 7), (5, 1), (6, 4), (7, 2)
#
# --- Loi giai 4: [0, 6, 4, 7, 1, 3, 5, 2] ---
# Q - - - - - - -
# - - - - - - Q -
# - - - - Q - - -
# - - - - - - - Q
# - Q - - - - - -
# - - - Q - - - -
# - - - - - Q - -
# - - Q - - - - -
# Toa do cac quan hau (hàng, cột): (0, 0), (1, 6), (2, 4), (3, 7), (4, 1), (5, 3), (6, 5), (7, 2)
#
# --- Loi giai 5: [1, 3, 5, 7, 2, 0, 6, 4] ---
# - Q - - - - - -
# - - - Q - - - -
# - - - - - Q - -
# - - - - - - - Q
# - - Q - - - - -
# Q - - - - - - -
# - - - - - - Q -
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 1), (1, 3), (2, 5), (3, 7), (4, 2), (5, 0), (6, 6), (7, 4)
#
# --- Loi giai 6: [1, 4, 6, 0, 2, 7, 5, 3] ---
# - Q - - - - - -
# - - - - Q - - -
# - - - - - - Q -
# Q - - - - - - -
# - - Q - - - - -
# - - - - - - - Q
# - - - - - Q - -
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 1), (1, 4), (2, 6), (3, 0), (4, 2), (5, 7), (6, 5), (7, 3)
#
# --- Loi giai 7: [1, 4, 6, 3, 0, 7, 5, 2] ---
# - Q - - - - - -
# - - - - Q - - -
# - - - - - - Q -
# - - - Q - - - -
# Q - - - - - - -
# - - - - - - - Q
# - - - - - Q - -
# - - Q - - - - -
# Toa do cac quan hau (hàng, cột): (0, 1), (1, 4), (2, 6), (3, 3), (4, 0), (5, 7), (6, 5), (7, 2)
#
# --- Loi giai 8: [1, 5, 0, 6, 3, 7, 2, 4] ---
# - Q - - - - - -
# - - - - - Q - -
# Q - - - - - - -
# - - - - - - Q -
# - - - Q - - - -
# - - - - - - - Q
# - - Q - - - - -
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 1), (1, 5), (2, 0), (3, 6), (4, 3), (5, 7), (6, 2), (7, 4)
#
# --- Loi giai 9: [1, 5, 7, 2, 0, 3, 6, 4] ---
# - Q - - - - - -
# - - - - - Q - -
# - - - - - - - Q
# - - Q - - - - -
# Q - - - - - - -
# - - - Q - - - -
# - - - - - - Q -
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 1), (1, 5), (2, 7), (3, 2), (4, 0), (5, 3), (6, 6), (7, 4)
#
# --- Loi giai 10: [1, 6, 2, 5, 7, 4, 0, 3] ---
# - Q - - - - - -
# - - - - - - Q -
# - - Q - - - - -
# - - - - - Q - -
# - - - - - - - Q
# - - - - Q - - -
# Q - - - - - - -
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 1), (1, 6), (2, 2), (3, 5), (4, 7), (5, 4), (6, 0), (7, 3)
#
# --- Loi giai 11: [1, 6, 4, 7, 0, 3, 5, 2] ---
# - Q - - - - - -
# - - - - - - Q -
# - - - - Q - - -
# - - - - - - - Q
# Q - - - - - - -
# - - - Q - - - -
# - - - - - Q - -
# - - Q - - - - -
# Toa do cac quan hau (hàng, cột): (0, 1), (1, 6), (2, 4), (3, 7), (4, 0), (5, 3), (6, 5), (7, 2)
#
# --- Loi giai 12: [1, 7, 5, 0, 2, 4, 6, 3] ---
# - Q - - - - - -
# - - - - - - - Q
# - - - - - Q - -
# Q - - - - - - -
# - - Q - - - - -
# - - - - Q - - -
# - - - - - - Q -
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 1), (1, 7), (2, 5), (3, 0), (4, 2), (5, 4), (6, 6), (7, 3)
#
# --- Loi giai 13: [2, 0, 6, 4, 7, 1, 3, 5] ---
# - - Q - - - - -
# Q - - - - - - -
# - - - - - - Q -
# - - - - Q - - -
# - - - - - - - Q
# - Q - - - - - -
# - - - Q - - - -
# - - - - - Q - -
# Toa do cac quan hau (hàng, cột): (0, 2), (1, 0), (2, 6), (3, 4), (4, 7), (5, 1), (6, 3), (7, 5)
#
# --- Loi giai 14: [2, 4, 1, 7, 0, 6, 3, 5] ---
# - - Q - - - - -
# - - - - Q - - -
# - Q - - - - - -
# - - - - - - - Q
# Q - - - - - - -
# - - - - - - Q -
# - - - Q - - - -
# - - - - - Q - -
# Toa do cac quan hau (hàng, cột): (0, 2), (1, 4), (2, 1), (3, 7), (4, 0), (5, 6), (6, 3), (7, 5)
#
# --- Loi giai 15: [2, 4, 1, 7, 5, 3, 6, 0] ---
# - - Q - - - - -
# - - - - Q - - -
# - Q - - - - - -
# - - - - - - - Q
# - - - - - Q - -
# - - - Q - - - -
# - - - - - - Q -
# Q - - - - - - -
# Toa do cac quan hau (hàng, cột): (0, 2), (1, 4), (2, 1), (3, 7), (4, 5), (5, 3), (6, 6), (7, 0)
#
# --- Loi giai 16: [2, 4, 6, 0, 3, 1, 7, 5] ---
# - - Q - - - - -
# - - - - Q - - -
# - - - - - - Q -
# Q - - - - - - -
# - - - Q - - - -
# - Q - - - - - -
# - - - - - - - Q
# - - - - - Q - -
# Toa do cac quan hau (hàng, cột): (0, 2), (1, 4), (2, 6), (3, 0), (4, 3), (5, 1), (6, 7), (7, 5)
#
# --- Loi giai 17: [2, 4, 7, 3, 0, 6, 1, 5] ---
# - - Q - - - - -
# - - - - Q - - -
# - - - - - - - Q
# - - - Q - - - -
# Q - - - - - - -
# - - - - - - Q -
# - Q - - - - - -
# - - - - - Q - -
# Toa do cac quan hau (hàng, cột): (0, 2), (1, 4), (2, 7), (3, 3), (4, 0), (5, 6), (6, 1), (7, 5)
#
# --- Loi giai 18: [2, 5, 1, 4, 7, 0, 6, 3] ---
# - - Q - - - - -
# - - - - - Q - -
# - Q - - - - - -
# - - - - Q - - -
# - - - - - - - Q
# Q - - - - - - -
# - - - - - - Q -
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 2), (1, 5), (2, 1), (3, 4), (4, 7), (5, 0), (6, 6), (7, 3)
#
# --- Loi giai 19: [2, 5, 1, 6, 0, 3, 7, 4] ---
# - - Q - - - - -
# - - - - - Q - -
# - Q - - - - - -
# - - - - - - Q -
# Q - - - - - - -
# - - - Q - - - -
# - - - - - - - Q
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 2), (1, 5), (2, 1), (3, 6), (4, 0), (5, 3), (6, 7), (7, 4)
#
# --- Loi giai 20: [2, 5, 1, 6, 4, 0, 7, 3] ---
# - - Q - - - - -
# - - - - - Q - -
# - Q - - - - - -
# - - - - - - Q -
# - - - - Q - - -
# Q - - - - - - -
# - - - - - - - Q
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 2), (1, 5), (2, 1), (3, 6), (4, 4), (5, 0), (6, 7), (7, 3)
#
# --- Loi giai 21: [2, 5, 3, 0, 7, 4, 6, 1] ---
# - - Q - - - - -
# - - - - - Q - -
# - - - Q - - - -
# Q - - - - - - -
# - - - - - - - Q
# - - - - Q - - -
# - - - - - - Q -
# - Q - - - - - -
# Toa do cac quan hau (hàng, cột): (0, 2), (1, 5), (2, 3), (3, 0), (4, 7), (5, 4), (6, 6), (7, 1)
#
# --- Loi giai 22: [2, 5, 3, 1, 7, 4, 6, 0] ---
# - - Q - - - - -
# - - - - - Q - -
# - - - Q - - - -
# - Q - - - - - -
# - - - - - - - Q
# - - - - Q - - -
# - - - - - - Q -
# Q - - - - - - -
# Toa do cac quan hau (hàng, cột): (0, 2), (1, 5), (2, 3), (3, 1), (4, 7), (5, 4), (6, 6), (7, 0)
#
# --- Loi giai 23: [2, 5, 7, 0, 3, 6, 4, 1] ---
# - - Q - - - - -
# - - - - - Q - -
# - - - - - - - Q
# Q - - - - - - -
# - - - Q - - - -
# - - - - - - Q -
# - - - - Q - - -
# - Q - - - - - -
# Toa do cac quan hau (hàng, cột): (0, 2), (1, 5), (2, 7), (3, 0), (4, 3), (5, 6), (6, 4), (7, 1)
#
# --- Loi giai 24: [2, 5, 7, 0, 4, 6, 1, 3] ---
# - - Q - - - - -
# - - - - - Q - -
# - - - - - - - Q
# Q - - - - - - -
# - - - - Q - - -
# - - - - - - Q -
# - Q - - - - - -
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 2), (1, 5), (2, 7), (3, 0), (4, 4), (5, 6), (6, 1), (7, 3)
#
# --- Loi giai 25: [2, 5, 7, 1, 3, 0, 6, 4] ---
# - - Q - - - - -
# - - - - - Q - -
# - - - - - - - Q
# - Q - - - - - -
# - - - Q - - - -
# Q - - - - - - -
# - - - - - - Q -
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 2), (1, 5), (2, 7), (3, 1), (4, 3), (5, 0), (6, 6), (7, 4)
#
# --- Loi giai 26: [2, 6, 1, 7, 4, 0, 3, 5] ---
# - - Q - - - - -
# - - - - - - Q -
# - Q - - - - - -
# - - - - - - - Q
# - - - - Q - - -
# Q - - - - - - -
# - - - Q - - - -
# - - - - - Q - -
# Toa do cac quan hau (hàng, cột): (0, 2), (1, 6), (2, 1), (3, 7), (4, 4), (5, 0), (6, 3), (7, 5)
#
# --- Loi giai 27: [2, 6, 1, 7, 5, 3, 0, 4] ---
# - - Q - - - - -
# - - - - - - Q -
# - Q - - - - - -
# - - - - - - - Q
# - - - - - Q - -
# - - - Q - - - -
# Q - - - - - - -
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 2), (1, 6), (2, 1), (3, 7), (4, 5), (5, 3), (6, 0), (7, 4)
#
# --- Loi giai 28: [2, 7, 3, 6, 0, 5, 1, 4] ---
# - - Q - - - - -
# - - - - - - - Q
# - - - Q - - - -
# - - - - - - Q -
# Q - - - - - - -
# - - - - - Q - -
# - Q - - - - - -
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 2), (1, 7), (2, 3), (3, 6), (4, 0), (5, 5), (6, 1), (7, 4)
#
# --- Loi giai 29: [3, 0, 4, 7, 1, 6, 2, 5] ---
# - - - Q - - - -
# Q - - - - - - -
# - - - - Q - - -
# - - - - - - - Q
# - Q - - - - - -
# - - - - - - Q -
# - - Q - - - - -
# - - - - - Q - -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 0), (2, 4), (3, 7), (4, 1), (5, 6), (6, 2), (7, 5)
#
# --- Loi giai 30: [3, 0, 4, 7, 5, 2, 6, 1] ---
# - - - Q - - - -
# Q - - - - - - -
# - - - - Q - - -
# - - - - - - - Q
# - - - - - Q - -
# - - Q - - - - -
# - - - - - - Q -
# - Q - - - - - -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 0), (2, 4), (3, 7), (4, 5), (5, 2), (6, 6), (7, 1)
#
# --- Loi giai 31: [3, 1, 4, 7, 5, 0, 2, 6] ---
# - - - Q - - - -
# - Q - - - - - -
# - - - - Q - - -
# - - - - - - - Q
# - - - - - Q - -
# Q - - - - - - -
# - - Q - - - - -
# - - - - - - Q -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 1), (2, 4), (3, 7), (4, 5), (5, 0), (6, 2), (7, 6)
#
# --- Loi giai 32: [3, 1, 6, 2, 5, 7, 0, 4] ---
# - - - Q - - - -
# - Q - - - - - -
# - - - - - - Q -
# - - Q - - - - -
# - - - - - Q - -
# - - - - - - - Q
# Q - - - - - - -
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 1), (2, 6), (3, 2), (4, 5), (5, 7), (6, 0), (7, 4)
#
# --- Loi giai 33: [3, 1, 6, 2, 5, 7, 4, 0] ---
# - - - Q - - - -
# - Q - - - - - -
# - - - - - - Q -
# - - Q - - - - -
# - - - - - Q - -
# - - - - - - - Q
# - - - - Q - - -
# Q - - - - - - -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 1), (2, 6), (3, 2), (4, 5), (5, 7), (6, 4), (7, 0)
#
# --- Loi giai 34: [3, 1, 6, 4, 0, 7, 5, 2] ---
# - - - Q - - - -
# - Q - - - - - -
# - - - - - - Q -
# - - - - Q - - -
# Q - - - - - - -
# - - - - - - - Q
# - - - - - Q - -
# - - Q - - - - -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 1), (2, 6), (3, 4), (4, 0), (5, 7), (6, 5), (7, 2)
#
# --- Loi giai 35: [3, 1, 7, 4, 6, 0, 2, 5] ---
# - - - Q - - - -
# - Q - - - - - -
# - - - - - - - Q
# - - - - Q - - -
# - - - - - - Q -
# Q - - - - - - -
# - - Q - - - - -
# - - - - - Q - -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 1), (2, 7), (3, 4), (4, 6), (5, 0), (6, 2), (7, 5)
#
# --- Loi giai 36: [3, 1, 7, 5, 0, 2, 4, 6] ---
# - - - Q - - - -
# - Q - - - - - -
# - - - - - - - Q
# - - - - - Q - -
# Q - - - - - - -
# - - Q - - - - -
# - - - - Q - - -
# - - - - - - Q -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 1), (2, 7), (3, 5), (4, 0), (5, 2), (6, 4), (7, 6)
#
# --- Loi giai 37: [3, 5, 0, 4, 1, 7, 2, 6] ---
# - - - Q - - - -
# - - - - - Q - -
# Q - - - - - - -
# - - - - Q - - -
# - Q - - - - - -
# - - - - - - - Q
# - - Q - - - - -
# - - - - - - Q -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 5), (2, 0), (3, 4), (4, 1), (5, 7), (6, 2), (7, 6)
#
# --- Loi giai 38: [3, 5, 7, 1, 6, 0, 2, 4] ---
# - - - Q - - - -
# - - - - - Q - -
# - - - - - - - Q
# - Q - - - - - -
# - - - - - - Q -
# Q - - - - - - -
# - - Q - - - - -
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 5), (2, 7), (3, 1), (4, 6), (5, 0), (6, 2), (7, 4)
#
# --- Loi giai 39: [3, 5, 7, 2, 0, 6, 4, 1] ---
# - - - Q - - - -
# - - - - - Q - -
# - - - - - - - Q
# - - Q - - - - -
# Q - - - - - - -
# - - - - - - Q -
# - - - - Q - - -
# - Q - - - - - -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 5), (2, 7), (3, 2), (4, 0), (5, 6), (6, 4), (7, 1)
#
# --- Loi giai 40: [3, 6, 0, 7, 4, 1, 5, 2] ---
# - - - Q - - - -
# - - - - - - Q -
# Q - - - - - - -
# - - - - - - - Q
# - - - - Q - - -
# - Q - - - - - -
# - - - - - Q - -
# - - Q - - - - -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 6), (2, 0), (3, 7), (4, 4), (5, 1), (6, 5), (7, 2)
#
# --- Loi giai 41: [3, 6, 2, 7, 1, 4, 0, 5] ---
# - - - Q - - - -
# - - - - - - Q -
# - - Q - - - - -
# - - - - - - - Q
# - Q - - - - - -
# - - - - Q - - -
# Q - - - - - - -
# - - - - - Q - -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 6), (2, 2), (3, 7), (4, 1), (5, 4), (6, 0), (7, 5)
#
# --- Loi giai 42: [3, 6, 4, 1, 5, 0, 2, 7] ---
# - - - Q - - - -
# - - - - - - Q -
# - - - - Q - - -
# - Q - - - - - -
# - - - - - Q - -
# Q - - - - - - -
# - - Q - - - - -
# - - - - - - - Q
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 6), (2, 4), (3, 1), (4, 5), (5, 0), (6, 2), (7, 7)
#
# --- Loi giai 43: [3, 6, 4, 2, 0, 5, 7, 1] ---
# - - - Q - - - -
# - - - - - - Q -
# - - - - Q - - -
# - - Q - - - - -
# Q - - - - - - -
# - - - - - Q - -
# - - - - - - - Q
# - Q - - - - - -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 6), (2, 4), (3, 2), (4, 0), (5, 5), (6, 7), (7, 1)
#
# --- Loi giai 44: [3, 7, 0, 2, 5, 1, 6, 4] ---
# - - - Q - - - -
# - - - - - - - Q
# Q - - - - - - -
# - - Q - - - - -
# - - - - - Q - -
# - Q - - - - - -
# - - - - - - Q -
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 7), (2, 0), (3, 2), (4, 5), (5, 1), (6, 6), (7, 4)
#
# --- Loi giai 45: [3, 7, 0, 4, 6, 1, 5, 2] ---
# - - - Q - - - -
# - - - - - - - Q
# Q - - - - - - -
# - - - - Q - - -
# - - - - - - Q -
# - Q - - - - - -
# - - - - - Q - -
# - - Q - - - - -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 7), (2, 0), (3, 4), (4, 6), (5, 1), (6, 5), (7, 2)
#
# --- Loi giai 46: [3, 7, 4, 2, 0, 6, 1, 5] ---
# - - - Q - - - -
# - - - - - - - Q
# - - - - Q - - -
# - - Q - - - - -
# Q - - - - - - -
# - - - - - - Q -
# - Q - - - - - -
# - - - - - Q - -
# Toa do cac quan hau (hàng, cột): (0, 3), (1, 7), (2, 4), (3, 2), (4, 0), (5, 6), (6, 1), (7, 5)
#
# --- Loi giai 47: [4, 0, 3, 5, 7, 1, 6, 2] ---
# - - - - Q - - -
# Q - - - - - - -
# - - - Q - - - -
# - - - - - Q - -
# - - - - - - - Q
# - Q - - - - - -
# - - - - - - Q -
# - - Q - - - - -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 0), (2, 3), (3, 5), (4, 7), (5, 1), (6, 6), (7, 2)
#
# --- Loi giai 48: [4, 0, 7, 3, 1, 6, 2, 5] ---
# - - - - Q - - -
# Q - - - - - - -
# - - - - - - - Q
# - - - Q - - - -
# - Q - - - - - -
# - - - - - - Q -
# - - Q - - - - -
# - - - - - Q - -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 0), (2, 7), (3, 3), (4, 1), (5, 6), (6, 2), (7, 5)
#
# --- Loi giai 49: [4, 0, 7, 5, 2, 6, 1, 3] ---
# - - - - Q - - -
# Q - - - - - - -
# - - - - - - - Q
# - - - - - Q - -
# - - Q - - - - -
# - - - - - - Q -
# - Q - - - - - -
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 0), (2, 7), (3, 5), (4, 2), (5, 6), (6, 1), (7, 3)
#
# --- Loi giai 50: [4, 1, 3, 5, 7, 2, 0, 6] ---
# - - - - Q - - -
# - Q - - - - - -
# - - - Q - - - -
# - - - - - Q - -
# - - - - - - - Q
# - - Q - - - - -
# Q - - - - - - -
# - - - - - - Q -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 1), (2, 3), (3, 5), (4, 7), (5, 2), (6, 0), (7, 6)
#
# --- Loi giai 51: [4, 1, 3, 6, 2, 7, 5, 0] ---
# - - - - Q - - -
# - Q - - - - - -
# - - - Q - - - -
# - - - - - - Q -
# - - Q - - - - -
# - - - - - - - Q
# - - - - - Q - -
# Q - - - - - - -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 1), (2, 3), (3, 6), (4, 2), (5, 7), (6, 5), (7, 0)
#
# --- Loi giai 52: [4, 1, 5, 0, 6, 3, 7, 2] ---
# - - - - Q - - -
# - Q - - - - - -
# - - - - - Q - -
# Q - - - - - - -
# - - - - - - Q -
# - - - Q - - - -
# - - - - - - - Q
# - - Q - - - - -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 1), (2, 5), (3, 0), (4, 6), (5, 3), (6, 7), (7, 2)
#
# --- Loi giai 53: [4, 1, 7, 0, 3, 6, 2, 5] ---
# - - - - Q - - -
# - Q - - - - - -
# - - - - - - - Q
# Q - - - - - - -
# - - - Q - - - -
# - - - - - - Q -
# - - Q - - - - -
# - - - - - Q - -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 1), (2, 7), (3, 0), (4, 3), (5, 6), (6, 2), (7, 5)
#
# --- Loi giai 54: [4, 2, 0, 5, 7, 1, 3, 6] ---
# - - - - Q - - -
# - - Q - - - - -
# Q - - - - - - -
# - - - - - Q - -
# - - - - - - - Q
# - Q - - - - - -
# - - - Q - - - -
# - - - - - - Q -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 2), (2, 0), (3, 5), (4, 7), (5, 1), (6, 3), (7, 6)
#
# --- Loi giai 55: [4, 2, 0, 6, 1, 7, 5, 3] ---
# - - - - Q - - -
# - - Q - - - - -
# Q - - - - - - -
# - - - - - - Q -
# - Q - - - - - -
# - - - - - - - Q
# - - - - - Q - -
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 2), (2, 0), (3, 6), (4, 1), (5, 7), (6, 5), (7, 3)
#
# --- Loi giai 56: [4, 2, 7, 3, 6, 0, 5, 1] ---
# - - - - Q - - -
# - - Q - - - - -
# - - - - - - - Q
# - - - Q - - - -
# - - - - - - Q -
# Q - - - - - - -
# - - - - - Q - -
# - Q - - - - - -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 2), (2, 7), (3, 3), (4, 6), (5, 0), (6, 5), (7, 1)
#
# --- Loi giai 57: [4, 6, 0, 2, 7, 5, 3, 1] ---
# - - - - Q - - -
# - - - - - - Q -
# Q - - - - - - -
# - - Q - - - - -
# - - - - - - - Q
# - - - - - Q - -
# - - - Q - - - -
# - Q - - - - - -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 6), (2, 0), (3, 2), (4, 7), (5, 5), (6, 3), (7, 1)
#
# --- Loi giai 58: [4, 6, 0, 3, 1, 7, 5, 2] ---
# - - - - Q - - -
# - - - - - - Q -
# Q - - - - - - -
# - - - Q - - - -
# - Q - - - - - -
# - - - - - - - Q
# - - - - - Q - -
# - - Q - - - - -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 6), (2, 0), (3, 3), (4, 1), (5, 7), (6, 5), (7, 2)
#
# --- Loi giai 59: [4, 6, 1, 3, 7, 0, 2, 5] ---
# - - - - Q - - -
# - - - - - - Q -
# - Q - - - - - -
# - - - Q - - - -
# - - - - - - - Q
# Q - - - - - - -
# - - Q - - - - -
# - - - - - Q - -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 6), (2, 1), (3, 3), (4, 7), (5, 0), (6, 2), (7, 5)
#
# --- Loi giai 60: [4, 6, 1, 5, 2, 0, 3, 7] ---
# - - - - Q - - -
# - - - - - - Q -
# - Q - - - - - -
# - - - - - Q - -
# - - Q - - - - -
# Q - - - - - - -
# - - - Q - - - -
# - - - - - - - Q
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 6), (2, 1), (3, 5), (4, 2), (5, 0), (6, 3), (7, 7)
#
# --- Loi giai 61: [4, 6, 1, 5, 2, 0, 7, 3] ---
# - - - - Q - - -
# - - - - - - Q -
# - Q - - - - - -
# - - - - - Q - -
# - - Q - - - - -
# Q - - - - - - -
# - - - - - - - Q
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 6), (2, 1), (3, 5), (4, 2), (5, 0), (6, 7), (7, 3)
#
# --- Loi giai 62: [4, 6, 3, 0, 2, 7, 5, 1] ---
# - - - - Q - - -
# - - - - - - Q -
# - - - Q - - - -
# Q - - - - - - -
# - - Q - - - - -
# - - - - - - - Q
# - - - - - Q - -
# - Q - - - - - -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 6), (2, 3), (3, 0), (4, 2), (5, 7), (6, 5), (7, 1)
#
# --- Loi giai 63: [4, 7, 3, 0, 2, 5, 1, 6] ---
# - - - - Q - - -
# - - - - - - - Q
# - - - Q - - - -
# Q - - - - - - -
# - - Q - - - - -
# - - - - - Q - -
# - Q - - - - - -
# - - - - - - Q -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 7), (2, 3), (3, 0), (4, 2), (5, 5), (6, 1), (7, 6)
#
# --- Loi giai 64: [4, 7, 3, 0, 6, 1, 5, 2] ---
# - - - - Q - - -
# - - - - - - - Q
# - - - Q - - - -
# Q - - - - - - -
# - - - - - - Q -
# - Q - - - - - -
# - - - - - Q - -
# - - Q - - - - -
# Toa do cac quan hau (hàng, cột): (0, 4), (1, 7), (2, 3), (3, 0), (4, 6), (5, 1), (6, 5), (7, 2)
#
# --- Loi giai 65: [5, 0, 4, 1, 7, 2, 6, 3] ---
# - - - - - Q - -
# Q - - - - - - -
# - - - - Q - - -
# - Q - - - - - -
# - - - - - - - Q
# - - Q - - - - -
# - - - - - - Q -
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 5), (1, 0), (2, 4), (3, 1), (4, 7), (5, 2), (6, 6), (7, 3)
#
# --- Loi giai 66: [5, 1, 6, 0, 2, 4, 7, 3] ---
# - - - - - Q - -
# - Q - - - - - -
# - - - - - - Q -
# Q - - - - - - -
# - - Q - - - - -
# - - - - Q - - -
# - - - - - - - Q
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 5), (1, 1), (2, 6), (3, 0), (4, 2), (5, 4), (6, 7), (7, 3)
#
# --- Loi giai 67: [5, 1, 6, 0, 3, 7, 4, 2] ---
# - - - - - Q - -
# - Q - - - - - -
# - - - - - - Q -
# Q - - - - - - -
# - - - Q - - - -
# - - - - - - - Q
# - - - - Q - - -
# - - Q - - - - -
# Toa do cac quan hau (hàng, cột): (0, 5), (1, 1), (2, 6), (3, 0), (4, 3), (5, 7), (6, 4), (7, 2)
#
# --- Loi giai 68: [5, 2, 0, 6, 4, 7, 1, 3] ---
# - - - - - Q - -
# - - Q - - - - -
# Q - - - - - - -
# - - - - - - Q -
# - - - - Q - - -
# - - - - - - - Q
# - Q - - - - - -
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 5), (1, 2), (2, 0), (3, 6), (4, 4), (5, 7), (6, 1), (7, 3)
#
# --- Loi giai 69: [5, 2, 0, 7, 3, 1, 6, 4] ---
# - - - - - Q - -
# - - Q - - - - -
# Q - - - - - - -
# - - - - - - - Q
# - - - Q - - - -
# - Q - - - - - -
# - - - - - - Q -
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 5), (1, 2), (2, 0), (3, 7), (4, 3), (5, 1), (6, 6), (7, 4)
#
# --- Loi giai 70: [5, 2, 0, 7, 4, 1, 3, 6] ---
# - - - - - Q - -
# - - Q - - - - -
# Q - - - - - - -
# - - - - - - - Q
# - - - - Q - - -
# - Q - - - - - -
# - - - Q - - - -
# - - - - - - Q -
# Toa do cac quan hau (hàng, cột): (0, 5), (1, 2), (2, 0), (3, 7), (4, 4), (5, 1), (6, 3), (7, 6)
#
# --- Loi giai 71: [5, 2, 4, 6, 0, 3, 1, 7] ---
# - - - - - Q - -
# - - Q - - - - -
# - - - - Q - - -
# - - - - - - Q -
# Q - - - - - - -
# - - - Q - - - -
# - Q - - - - - -
# - - - - - - - Q
# Toa do cac quan hau (hàng, cột): (0, 5), (1, 2), (2, 4), (3, 6), (4, 0), (5, 3), (6, 1), (7, 7)
#
# --- Loi giai 72: [5, 2, 4, 7, 0, 3, 1, 6] ---
# - - - - - Q - -
# - - Q - - - - -
# - - - - Q - - -
# - - - - - - - Q
# Q - - - - - - -
# - - - Q - - - -
# - Q - - - - - -
# - - - - - - Q -
# Toa do cac quan hau (hàng, cột): (0, 5), (1, 2), (2, 4), (3, 7), (4, 0), (5, 3), (6, 1), (7, 6)
#
# --- Loi giai 73: [5, 2, 6, 1, 3, 7, 0, 4] ---
# - - - - - Q - -
# - - Q - - - - -
# - - - - - - Q -
# - Q - - - - - -
# - - - Q - - - -
# - - - - - - - Q
# Q - - - - - - -
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 5), (1, 2), (2, 6), (3, 1), (4, 3), (5, 7), (6, 0), (7, 4)
#
# --- Loi giai 74: [5, 2, 6, 1, 7, 4, 0, 3] ---
# - - - - - Q - -
# - - Q - - - - -
# - - - - - - Q -
# - Q - - - - - -
# - - - - - - - Q
# - - - - Q - - -
# Q - - - - - - -
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 5), (1, 2), (2, 6), (3, 1), (4, 7), (5, 4), (6, 0), (7, 3)
#
# --- Loi giai 75: [5, 2, 6, 3, 0, 7, 1, 4] ---
# - - - - - Q - -
# - - Q - - - - -
# - - - - - - Q -
# - - - Q - - - -
# Q - - - - - - -
# - - - - - - - Q
# - Q - - - - - -
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 5), (1, 2), (2, 6), (3, 3), (4, 0), (5, 7), (6, 1), (7, 4)
#
# --- Loi giai 76: [5, 3, 0, 4, 7, 1, 6, 2] ---
# - - - - - Q - -
# - - - Q - - - -
# Q - - - - - - -
# - - - - Q - - -
# - - - - - - - Q
# - Q - - - - - -
# - - - - - - Q -
# - - Q - - - - -
# Toa do cac quan hau (hàng, cột): (0, 5), (1, 3), (2, 0), (3, 4), (4, 7), (5, 1), (6, 6), (7, 2)
#
# --- Loi giai 77: [5, 3, 1, 7, 4, 6, 0, 2] ---
# - - - - - Q - -
# - - - Q - - - -
# - Q - - - - - -
# - - - - - - - Q
# - - - - Q - - -
# - - - - - - Q -
# Q - - - - - - -
# - - Q - - - - -
# Toa do cac quan hau (hàng, cột): (0, 5), (1, 3), (2, 1), (3, 7), (4, 4), (5, 6), (6, 0), (7, 2)
#
# --- Loi giai 78: [5, 3, 6, 0, 2, 4, 1, 7] ---
# - - - - - Q - -
# - - - Q - - - -
# - - - - - - Q -
# Q - - - - - - -
# - - Q - - - - -
# - - - - Q - - -
# - Q - - - - - -
# - - - - - - - Q
# Toa do cac quan hau (hàng, cột): (0, 5), (1, 3), (2, 6), (3, 0), (4, 2), (5, 4), (6, 1), (7, 7)
#
# --- Loi giai 79: [5, 3, 6, 0, 7, 1, 4, 2] ---
# - - - - - Q - -
# - - - Q - - - -
# - - - - - - Q -
# Q - - - - - - -
# - - - - - - - Q
# - Q - - - - - -
# - - - - Q - - -
# - - Q - - - - -
# Toa do cac quan hau (hàng, cột): (0, 5), (1, 3), (2, 6), (3, 0), (4, 7), (5, 1), (6, 4), (7, 2)
#
# --- Loi giai 80: [5, 7, 1, 3, 0, 6, 4, 2] ---
# - - - - - Q - -
# - - - - - - - Q
# - Q - - - - - -
# - - - Q - - - -
# Q - - - - - - -
# - - - - - - Q -
# - - - - Q - - -
# - - Q - - - - -
# Toa do cac quan hau (hàng, cột): (0, 5), (1, 7), (2, 1), (3, 3), (4, 0), (5, 6), (6, 4), (7, 2)
#
# --- Loi giai 81: [6, 0, 2, 7, 5, 3, 1, 4] ---
# - - - - - - Q -
# Q - - - - - - -
# - - Q - - - - -
# - - - - - - - Q
# - - - - - Q - -
# - - - Q - - - -
# - Q - - - - - -
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 6), (1, 0), (2, 2), (3, 7), (4, 5), (5, 3), (6, 1), (7, 4)
#
# --- Loi giai 82: [6, 1, 3, 0, 7, 4, 2, 5] ---
# - - - - - - Q -
# - Q - - - - - -
# - - - Q - - - -
# Q - - - - - - -
# - - - - - - - Q
# - - - - Q - - -
# - - Q - - - - -
# - - - - - Q - -
# Toa do cac quan hau (hàng, cột): (0, 6), (1, 1), (2, 3), (3, 0), (4, 7), (5, 4), (6, 2), (7, 5)
#
# --- Loi giai 83: [6, 1, 5, 2, 0, 3, 7, 4] ---
# - - - - - - Q -
# - Q - - - - - -
# - - - - - Q - -
# - - Q - - - - -
# Q - - - - - - -
# - - - Q - - - -
# - - - - - - - Q
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 6), (1, 1), (2, 5), (3, 2), (4, 0), (5, 3), (6, 7), (7, 4)
#
# --- Loi giai 84: [6, 2, 0, 5, 7, 4, 1, 3] ---
# - - - - - - Q -
# - - Q - - - - -
# Q - - - - - - -
# - - - - - Q - -
# - - - - - - - Q
# - - - - Q - - -
# - Q - - - - - -
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 6), (1, 2), (2, 0), (3, 5), (4, 7), (5, 4), (6, 1), (7, 3)
#
# --- Loi giai 85: [6, 2, 7, 1, 4, 0, 5, 3] ---
# - - - - - - Q -
# - - Q - - - - -
# - - - - - - - Q
# - Q - - - - - -
# - - - - Q - - -
# Q - - - - - - -
# - - - - - Q - -
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 6), (1, 2), (2, 7), (3, 1), (4, 4), (5, 0), (6, 5), (7, 3)
#
# --- Loi giai 86: [6, 3, 1, 4, 7, 0, 2, 5] ---
# - - - - - - Q -
# - - - Q - - - -
# - Q - - - - - -
# - - - - Q - - -
# - - - - - - - Q
# Q - - - - - - -
# - - Q - - - - -
# - - - - - Q - -
# Toa do cac quan hau (hàng, cột): (0, 6), (1, 3), (2, 1), (3, 4), (4, 7), (5, 0), (6, 2), (7, 5)
#
# --- Loi giai 87: [6, 3, 1, 7, 5, 0, 2, 4] ---
# - - - - - - Q -
# - - - Q - - - -
# - Q - - - - - -
# - - - - - - - Q
# - - - - - Q - -
# Q - - - - - - -
# - - Q - - - - -
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 6), (1, 3), (2, 1), (3, 7), (4, 5), (5, 0), (6, 2), (7, 4)
#
# --- Loi giai 88: [6, 4, 2, 0, 5, 7, 1, 3] ---
# - - - - - - Q -
# - - - - Q - - -
# - - Q - - - - -
# Q - - - - - - -
# - - - - - Q - -
# - - - - - - - Q
# - Q - - - - - -
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 6), (1, 4), (2, 2), (3, 0), (4, 5), (5, 7), (6, 1), (7, 3)
#
# --- Loi giai 89: [7, 1, 3, 0, 6, 4, 2, 5] ---
# - - - - - - - Q
# - Q - - - - - -
# - - - Q - - - -
# Q - - - - - - -
# - - - - - - Q -
# - - - - Q - - -
# - - Q - - - - -
# - - - - - Q - -
# Toa do cac quan hau (hàng, cột): (0, 7), (1, 1), (2, 3), (3, 0), (4, 6), (5, 4), (6, 2), (7, 5)
#
# --- Loi giai 90: [7, 1, 4, 2, 0, 6, 3, 5] ---
# - - - - - - - Q
# - Q - - - - - -
# - - - - Q - - -
# - - Q - - - - -
# Q - - - - - - -
# - - - - - - Q -
# - - - Q - - - -
# - - - - - Q - -
# Toa do cac quan hau (hàng, cột): (0, 7), (1, 1), (2, 4), (3, 2), (4, 0), (5, 6), (6, 3), (7, 5)
#
# --- Loi giai 91: [7, 2, 0, 5, 1, 4, 6, 3] ---
# - - - - - - - Q
# - - Q - - - - -
# Q - - - - - - -
# - - - - - Q - -
# - Q - - - - - -
# - - - - Q - - -
# - - - - - - Q -
# - - - Q - - - -
# Toa do cac quan hau (hàng, cột): (0, 7), (1, 2), (2, 0), (3, 5), (4, 1), (5, 4), (6, 6), (7, 3)
#
# --- Loi giai 92: [7, 3, 0, 2, 5, 1, 6, 4] ---
# - - - - - - - Q
# - - - Q - - - -
# Q - - - - - - -
# - - Q - - - - -
# - - - - - Q - -
# - Q - - - - - -
# - - - - - - Q -
# - - - - Q - - -
# Toa do cac quan hau (hàng, cột): (0, 7), (1, 3), (2, 0), (3, 2), (4, 5), (5, 1), (6, 6), (7, 4)
